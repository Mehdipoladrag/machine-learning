# %%
import numpy as np
import pandas as pd
import seaborn 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import warnings

# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset("tips")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.displot(data=df, x='tip', hue='sex', multiple="stack")
plt.show()

# %%
g = sns.displot(data=df, x='tip', hue='sex', kde=True, aspect=3, height=6)
plt.show()

# %%
sns.catplot(data=df, x='total_bill',y='sex', hue='smoker',kind="box")
plt.show()

# %%
g = sns.relplot(
    data=df,
    x='total_bill',
    y='tip',
    hue='smoker',
    style='smoker',
    size='size',
    col='sex',
    kind="line",
    facet_kws=dict(sharex=False)
)
g.set_axis_labels("Total Bill", "Tip")
g.set_titles("{col_name} customers")
plt.show()

# %%
sns.lmplot(data=df, x="total_bill", y="tip", col="time", hue="smoker")
plt.show()

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
sns.heatmap(data=corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df.replace({ 'sex': {'Male': 0, 'Female': 1}, 'smoker': {'No': 0, 'Yes': 1}}, inplace=True)
df.head(2)
# Out:
#    total_bill   tip sex smoker  day    time  size
# 0       16.99  1.01   1      0  Sun  Dinner     2
# 1       10.34  1.66   0      0  Sun  Dinner     3

# %%
df.replace({ 'sex': {'Male': 0, 'Female': 1}, 'smoker': {'No': 0, 'Yes': 1}}, inplace=True)
df.head(2)
# Out:
#    total_bill   tip sex smoker  day    time  size
# 0       16.99  1.01   1      0  Sun  Dinner     2
# 1       10.34  1.66   0      0  Sun  Dinner     3

# %%
days = pd.get_dummies(df['day'], dtype=int)
df = pd.concat([df, days], axis=1)
days.sample(5)
# Out:
#      Thur  Fri  Sat  Sun
# 171     0    0    1    0
# 140     1    0    0    0
# 101     0    1    0    0
# 238     0    0    1    0
# 62      0    0    1    0

# %%
times = pd.get_dummies(df['time'], dtype=int)
df = pd.concat([df, times], axis=1)
days.sample(5)
# Out:
#      Thur  Fri  Sat  Sun
# 8       0    0    0    1
# 25      0    0    1    0
# 135     1    0    0    0
# 133     1    0    0    0
# 85      1    0    0    0

# %%
df.head(2)
# Out:
#    total_bill   tip sex smoker  day    time  size  Thur  Fri  Sat  Sun  Lunch  \
# 0       16.99  1.01   1      0  Sun  Dinner     2     0    0    0    1      0
# 1       10.34  1.66   0      0  Sun  Dinner     3     0    0    0    1      0
#
#    Dinner
# 0       1
# 1       1

# %%
X = df[['sex', 'smoker', 'size', 'Fri', 'Sat', 'Sun', 'Dinner']]
Y = df[['tip']]

# %%
X
# Out:
#     sex smoker  size  Fri  Sat  Sun  Dinner
# 0     1      0     2    0    0    1       1
# 1     0      0     3    0    0    1       1
# 2     0      0     3    0    0    1       1
# 3     0      0     2    0    0    1       1
# 4     1      0     4    0    0    1       1
# ..   ..    ...   ...  ...  ...  ...     ...
# 239   0      0     3    0    1    0       1
# 240   1      1     2    0    1    0       1
# 241   0      1     2    0    1    0       1
# 242   0      0     2    0    1    0       1
# 243   1      0     2    0    0    0       1
#
# [244 rows x 7 columns]

# %%
Y
# Out:
#       tip
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# ..    ...
# 239  5.92
# 240  2.00
# 241  2.00
# 242  1.75
# 243  3.00
#
# [244 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=26)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = regressor.predict(X_test)

# %%
prediction
# Out:
# array([[2.41307932],
#        [2.00446276],
#        [2.41307932],
#        [4.11118843],
#        [5.2185532 ],
#        [4.43551409],
#        [3.35045009],
#        [2.87257137],
#        [2.41569958],
#        [3.40981996],
#        [2.70845149],
#        [2.93194124],
#        [2.63918933],
#        [4.05181856],
#        [4.11118843],
#        [2.70845149],
#        [2.41569958],
#        [3.35045009],
#        [4.33467818],
#        [2.42307646],
#        [2.41569958],
#        [2.41307932],
#        [2.93194124],
#        [3.11706805],
#        [3.34782983],
#        [3.63330971],
#        [5.22117346],
#        [2.64908162],
#        [2.70845149],
#        [2.70583123],
#        [4.11118843],
#        [3.57393984],
#        [3.63330971],
#        [2.92932099],
#        [3.35045009],
#        [2.70845149],
#        [3.03277715],
#        [2.22795252],
#        [3.4071997 ],
#        [2.92932099],
#        [2.41569958],
#        [4.51980499],
#        [1.72170799],
#        [2.87257137],
#        [2.63656907],
#        [2.70583123],
#        [2.64908162],
#        [2.64646136],
#        [2.63918933],
#        [2.63918933],
#        [2.64908162],
#        [2.92932099],
#        [2.70845149],
#        [2.41307932],
#        [2.86995111],
#        [4.75318703],
#        [3.03015689],
#        [3.33793754],
#        [3.03015689],
#        [2.80666713],
#        [2.41307932]])

# %%
X_test
# Out:
#     sex smoker  size  Fri  Sat  Sun  Dinner
# 135   1      0     2    0    0    0       0
# 111   1      0     1    0    1    0       1
# 124   1      0     2    0    0    0       0
# 227   0      0     4    0    1    0       1
# 125   1      0     6    0    0    0       0
# ..   ..    ...   ...  ...  ...  ...     ...
# 100   1      1     2    1    0    0       1
# 205   1      1     3    0    0    0       0
# 92    1      1     2    1    0    0       1
# 94    1      0     2    1    0    0       1
# 136   1      0     2    0    0    0       0
#
# [61 rows x 7 columns]

# %%
y_test
# Out:
#       tip
# 135  1.25
# 111  1.00
# 124  2.52
# 227  3.00
# 125  4.20
# ..    ...
# 100  2.50
# 205  3.23
# 92   1.00
# 94   3.25
# 136  2.00
#
# [61 rows x 1 columns]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, prediction))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, prediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# Mean Absolute Error: 0.6918601800051097
# Mean Squared Error: 0.7790431554801625
# Root Mean Squared Error: 0.8826342138622105

# %%
new_customer = np.array([0,1,3,1,0,0,0]).reshape(1,-1)
regressor.predict(new_customer)
# Out:
# array([[3.12444493]])
